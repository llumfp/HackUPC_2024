# %%
import pandas as pd
import numpy as np

# %%
# Lee el archivo CSV
df = pd.read_csv('products.csv', sep=';')

# %%
df
# Out:
#        id                                      name           ean
# 0       1             CALIERCORTIN 4mg/ml- 50ml iny  8.422320e+12
# 1      12               ADTAB GATO 12mg 0,5-2kg 1cp  5.420037e+12
# 2      23                 ADTAB GATO 48mg 2-8kg 1cp  5.420037e+12
# 3      34                      NICILAN 200/50 120cp  8.437003e+12
# 4      45                FORTEKOR SABOR 2,5mg- 28cp  5.703188e+12
# 5      56                             CONOFITE 20ml  5.703188e+12
# 6      67      OTOCLEAN LIMPIADOR- OTOLOGICO 18x5ml  5.703188e+12
# 7      78                             OXISPEED 60cp  8.713184e+12
# 8      89                              OTINET 125ml  3.661103e+12
# 9     100                              IRC-VET 60cp  5.701170e+12
# 10    111         PAÑO BUSTER POLIETILENO- 90x120cm  5.701170e+12
# 11    122          PAÑO BUSTER POLIETILENO- 60x90cm  8.410357e+12
# 12    133        PAÑO BUSTER POLIETILENO- 120x120cm  8.713184e+12
# 13    144                     CANINSULIN 10x2,50ml-  8.713184e+12
# 14    155                          GLUCANTIME 5x5ml  8.436530e+12
# 15    166                            LUBRITHAL 10gr  8.436026e+12
# 16    177                  CLEAN AURAL CANINO 100ml           NaN
# 17    188                             T-61 50ml iny           NaN
# 18    199                         SCALIBOR GDE 65cm           NaN
# 19    210                         SCALIBOR PEQ 48cm           NaN
# 20    221                          DEXABIOPEN 100ml  4.022495e+12
# 21    232                          DEPO-MODERIN 5ml  4.022496e+12
# 22    243           CONTENEDOR PARA- MUESTRAS 150ml  4.030539e+12
# 23    254  AGUJA STERICAN AMARILLA-20G 0,9X25mm100u  4.049501e+12
# 24    265   AGUJA STERICAN AZUL 23G- 0,6x25mm 100un  4.052200e+12
# 25    276  AGUJA STERICAN NARANJA-25G 0,5x16mm100un  8.414042e+12
# 26    287    JERINGA INJEKT 2CUERPOS- S/A 2ml 100un  8.437003e+12
# 27    298               DISCOFIX C/ALARGADERA- 75cm  8.713184e+12
# 28    309        PROPOFOL LIPURO 1%- BRAUN VET 50ml  5.701170e+12
# 29    320       ESPARADRAPO OMNIPLAST- CARNE 5cmx5m           NaN
# 30    331           VENDA ELASTICA LASTOTEL- 6cmx4m  5.600788e+12
# 31    342                         VETREGUL GEL 50ml  3.411113e+12
# 32    353           HYALORAL RZ GDES Y- GIGAN 120cp  8.414042e+12
# 33    364                              LEVENTA 30ml  8.436021e+12
# 34    375                       VETORYL 10mg 30caps  8.414042e+12
# 35    386                                SEDIN 10ml  8.414042e+12
# 36    397                           OMNIMATRIX 20gr  8.414042e+12
# 37    408                       MELOXIDYL GATO 15ml  4.028692e+12
# 38    419                              DAFORTE 20ml  8.713184e+12
# 39    430               ANIMA STRATH TOMILLO- 100ml  8.713184e+12
# 40    441           HYALORAL RZ GDES Y- GIGAN 360cp  8.713184e+12
# 41    452            HYALORAL CACHORRO Y- GATO 50ml  8.713184e+12
# 42    463                              DAFORTE 50ml  8.470006e+12
# 43    474                      SEMINTRA 4MG/ML 30ML  8.437012e+12
# 44    485              BRAVECTO 250mg 4,5-10kg 1tab           NaN
# 45    496               BRAVECTO 500mg 10-20kg 1tab  3.660176e+12
# 46    507              BRAVECTO 1000mg 20-40kg 1tab  3.411112e+12
# 47    518              BRAVECTO 1400mg 40-56kg 1tab  3.660176e+12
# 48    529                        CARPROX 20mg 100cp  8.414042e+12
# 49    540                           CONTINENZA 50ml  8.436026e+12
# 50    551            CONTENEDOR PARA- MUESTRAS 60ml  8.436026e+12
# 51    562                          LIBEO 10mg 120cp  8.436026e+12
# 52    573                   MELOXIDYL GATO oral 5ml  8.436026e+12
# 53    584     ZODON PERRO Y GATO ORAL- 25mg/ml 20ml  8.436026e+12
# 54    595                        LACRISTAL NEO 10ml  5.420037e+12
# 55    606            VERSICAN PLUS DHPPIL4R-25dosis  3.858889e+12
# 56    617             VERSICAN PLUS DHPPIL4-25dosis  3.858889e+12
# 57    628          SIMPARICA PERROS 5-10kg 20mg 3cp  8.431167e+12
# 58    639         SIMPARICA PERROS 10-20kg 40mg 3cp  3.411112e+12
# 59    650         SIMPARICA PERROS 20-40kg 80mg 3cp  3.411112e+12
# 60    661          FORTEKOR PLUS- 1,25/2,5mg 30tabs  3.700455e+12
# 61    672                   PREDNICORTONE 20mg 30cp  9.010854e+12
# 62    683                    PREDNICORTONE 5mg 30cp  8.429949e+12
# 63    694                  LETIFEND LEISHMANIA 10ds  8.436026e+12
# 64    705           CARPRODYL QUADRI 120mg- x 120cp  7.613203e+12
# 65    716            CARPRODYL QUADRI 50mg x- 100cp  8.422320e+12
# 66    727                        SOLIPHEN 60mg 60cp  8.414042e+12
# 67    738                            BUTOMIDOR 10ml  5.274203e+10
# 68    749                      TUSHEEL JARABE 150ml  3.411113e+12
# 69    760  STRONGHOLD PLUS GATO 30/5mg 2,5-5kg 6pip  3.411113e+12
# 70    771   PROLONGADOR REGULADOR- FLUJO 59cm 4,1ml  3.411113e+12
# 71    782                           MERLIN 65cm 2un  8.436026e+12
# 72    793                             NACOTIL 125ml  8.436026e+12
# 73    804      CANINE GASTROINTESTINAL- BIOME 1,5kg  8.436026e+12
# 74    815             VECTRA 3D PERRO 4-10kg  12pip           NaN
# 75    826            VECTRA 3D PERRO 10-25kg  12pip  3.411113e+12
# 76    837            VECTRA 3D PERRO 25-40kg  12pip  5.600788e+12
# 77    848          SIMPARICA TRIO PERROS 5-10kg 3cp  8.414042e+12
# 78    859         SIMPARICA TRIO PERROS 10-20kg 3cp  8.414042e+12
# 79    870         SIMPARICA TRIO PERROS 20-40kg 3cp           NaN
# 80    881                     ZELYS 1,25mg 8x12tabs  7.613039e+12
# 81    892                      OMNICARDIO PLUS 60cp  8.436005e+12
# 82    903  PLASMORAL DIGEST RZ PEQ- Y MED 30 sobres  8.436026e+12
# 83    914  PLASMORAL DIGEST RZ GDE-Y GIGAN 30sobres  8.719875e+12
# 84    925         EMPAPADORES MEDLINE- 60x90cm 25un  8.719875e+12
# 85    936    SANICAT CLUMPING VAINILLA-MANDARINA 8L  5.274204e+10
# 86    947  PROPLAN FELINE HYDRA-CARE HYDRAT 10x85gr  8.414042e+12
# 87    958    DESINCLOR CLORHEXIDINA- ACUOSA 1% 50ml  8.435458e+12
# 88    969                    LIBRELA 30mg iny 2x1ml  8.414042e+12
# 89    980                    DEXACORTONE 0,5mg 10cp  8.414042e+12
# 90    991                      DEXACORTONE 2mg 10cp  8.436589e+12
# 91   1002  CANINE I/D STEW POLLO-VEGETALES 12x354gr  8.414042e+12
# 92   1013                   PLASMORAL IMMUNITY 60cp  8.414042e+12
# 93   1024      PLAQTIV+ ADITIVO PARA- EL AGUA 500ml  8.414042e+12
# 94   1035       HEPATOSIL PLUS RAZAS- PEQUEÑAS 60cp  8.414042e+12
# 95   1046       HEPATOSIL PLUS RAZAS- MEDIANAS 30cp  3.411112e+12
# 96   1057                   VETILEA GASTRO GEL 50ml           NaN
# 97   1068        HEPATOSIL PLUS RAZAS- GRANDES 30cp           NaN
# 98   1079                      VETGASTRIL PLUS 20ml           NaN
# 99   1090                      VETGASTRIL PLUS 50ml           NaN
# 100  1101               IRC-VET GEL PERRO GATO 50ml           NaN
# 101  1112                    DERMIPRED 20mg 10x10cp           NaN

# %%
# Añade una columna llamada "cantidad" con valores aleatorios entre 0 y 10
df['cantidad'] = np.random.randint(0, 11, size=len(df))
df
# Out:
#        id                                      name           ean  cantidad
# 0       1             CALIERCORTIN 4mg/ml- 50ml iny  8.422320e+12         1
# 1      12               ADTAB GATO 12mg 0,5-2kg 1cp  5.420037e+12         5
# 2      23                 ADTAB GATO 48mg 2-8kg 1cp  5.420037e+12         1
# 3      34                      NICILAN 200/50 120cp  8.437003e+12         4
# 4      45                FORTEKOR SABOR 2,5mg- 28cp  5.703188e+12         8
# 5      56                             CONOFITE 20ml  5.703188e+12         7
# 6      67      OTOCLEAN LIMPIADOR- OTOLOGICO 18x5ml  5.703188e+12         7
# 7      78                             OXISPEED 60cp  8.713184e+12         5
# 8      89                              OTINET 125ml  3.661103e+12         8
# 9     100                              IRC-VET 60cp  5.701170e+12         9
# 10    111         PAÑO BUSTER POLIETILENO- 90x120cm  5.701170e+12         0
# 11    122          PAÑO BUSTER POLIETILENO- 60x90cm  8.410357e+12        10
# 12    133        PAÑO BUSTER POLIETILENO- 120x120cm  8.713184e+12         6
# 13    144                     CANINSULIN 10x2,50ml-  8.713184e+12         9
# 14    155                          GLUCANTIME 5x5ml  8.436530e+12         5
# 15    166                            LUBRITHAL 10gr  8.436026e+12         2
# 16    177                  CLEAN AURAL CANINO 100ml           NaN         9
# 17    188                             T-61 50ml iny           NaN         8
# 18    199                         SCALIBOR GDE 65cm           NaN         7
# 19    210                         SCALIBOR PEQ 48cm           NaN         3
# 20    221                          DEXABIOPEN 100ml  4.022495e+12         2
# 21    232                          DEPO-MODERIN 5ml  4.022496e+12         3
# 22    243           CONTENEDOR PARA- MUESTRAS 150ml  4.030539e+12         9
# 23    254  AGUJA STERICAN AMARILLA-20G 0,9X25mm100u  4.049501e+12         6
# 24    265   AGUJA STERICAN AZUL 23G- 0,6x25mm 100un  4.052200e+12         1
# 25    276  AGUJA STERICAN NARANJA-25G 0,5x16mm100un  8.414042e+12         4
# 26    287    JERINGA INJEKT 2CUERPOS- S/A 2ml 100un  8.437003e+12         7
# 27    298               DISCOFIX C/ALARGADERA- 75cm  8.713184e+12         9
# 28    309        PROPOFOL LIPURO 1%- BRAUN VET 50ml  5.701170e+12         4
# 29    320       ESPARADRAPO OMNIPLAST- CARNE 5cmx5m           NaN        10
# 30    331           VENDA ELASTICA LASTOTEL- 6cmx4m  5.600788e+12         1
# 31    342                         VETREGUL GEL 50ml  3.411113e+12        10
# 32    353           HYALORAL RZ GDES Y- GIGAN 120cp  8.414042e+12         3
# 33    364                              LEVENTA 30ml  8.436021e+12         8
# 34    375                       VETORYL 10mg 30caps  8.414042e+12         0
# 35    386                                SEDIN 10ml  8.414042e+12         6
# 36    397                           OMNIMATRIX 20gr  8.414042e+12         7
# 37    408                       MELOXIDYL GATO 15ml  4.028692e+12         4
# 38    419                              DAFORTE 20ml  8.713184e+12         6
# 39    430               ANIMA STRATH TOMILLO- 100ml  8.713184e+12         8
# 40    441           HYALORAL RZ GDES Y- GIGAN 360cp  8.713184e+12         3
# 41    452            HYALORAL CACHORRO Y- GATO 50ml  8.713184e+12         4
# 42    463                              DAFORTE 50ml  8.470006e+12         2
# 43    474                      SEMINTRA 4MG/ML 30ML  8.437012e+12         2
# 44    485              BRAVECTO 250mg 4,5-10kg 1tab           NaN         5
# 45    496               BRAVECTO 500mg 10-20kg 1tab  3.660176e+12        10
# 46    507              BRAVECTO 1000mg 20-40kg 1tab  3.411112e+12         0
# 47    518              BRAVECTO 1400mg 40-56kg 1tab  3.660176e+12         1
# 48    529                        CARPROX 20mg 100cp  8.414042e+12         2
# 49    540                           CONTINENZA 50ml  8.436026e+12         5
# 50    551            CONTENEDOR PARA- MUESTRAS 60ml  8.436026e+12         9
# 51    562                          LIBEO 10mg 120cp  8.436026e+12         1
# 52    573                   MELOXIDYL GATO oral 5ml  8.436026e+12         4
# 53    584     ZODON PERRO Y GATO ORAL- 25mg/ml 20ml  8.436026e+12         7
# 54    595                        LACRISTAL NEO 10ml  5.420037e+12        10
# 55    606            VERSICAN PLUS DHPPIL4R-25dosis  3.858889e+12         4
# 56    617             VERSICAN PLUS DHPPIL4-25dosis  3.858889e+12         5
# 57    628          SIMPARICA PERROS 5-10kg 20mg 3cp  8.431167e+12         3
# 58    639         SIMPARICA PERROS 10-20kg 40mg 3cp  3.411112e+12        10
# 59    650         SIMPARICA PERROS 20-40kg 80mg 3cp  3.411112e+12         1
# 60    661          FORTEKOR PLUS- 1,25/2,5mg 30tabs  3.700455e+12         4
# 61    672                   PREDNICORTONE 20mg 30cp  9.010854e+12         3
# 62    683                    PREDNICORTONE 5mg 30cp  8.429949e+12        10
# 63    694                  LETIFEND LEISHMANIA 10ds  8.436026e+12         9
# 64    705           CARPRODYL QUADRI 120mg- x 120cp  7.613203e+12         3
# 65    716            CARPRODYL QUADRI 50mg x- 100cp  8.422320e+12         8
# 66    727                        SOLIPHEN 60mg 60cp  8.414042e+12         0
# 67    738                            BUTOMIDOR 10ml  5.274203e+10         2
# 68    749                      TUSHEEL JARABE 150ml  3.411113e+12         8
# 69    760  STRONGHOLD PLUS GATO 30/5mg 2,5-5kg 6pip  3.411113e+12         2
# 70    771   PROLONGADOR REGULADOR- FLUJO 59cm 4,1ml  3.411113e+12         9
# 71    782                           MERLIN 65cm 2un  8.436026e+12         1
# 72    793                             NACOTIL 125ml  8.436026e+12         4
# 73    804      CANINE GASTROINTESTINAL- BIOME 1,5kg  8.436026e+12         6
# 74    815             VECTRA 3D PERRO 4-10kg  12pip           NaN         5
# 75    826            VECTRA 3D PERRO 10-25kg  12pip  3.411113e+12         2
# 76    837            VECTRA 3D PERRO 25-40kg  12pip  5.600788e+12         8
# 77    848          SIMPARICA TRIO PERROS 5-10kg 3cp  8.414042e+12         2
# 78    859         SIMPARICA TRIO PERROS 10-20kg 3cp  8.414042e+12         5
# 79    870         SIMPARICA TRIO PERROS 20-40kg 3cp           NaN         9
# 80    881                     ZELYS 1,25mg 8x12tabs  7.613039e+12        10
# 81    892                      OMNICARDIO PLUS 60cp  8.436005e+12         0
# 82    903  PLASMORAL DIGEST RZ PEQ- Y MED 30 sobres  8.436026e+12         7
# 83    914  PLASMORAL DIGEST RZ GDE-Y GIGAN 30sobres  8.719875e+12         1
# 84    925         EMPAPADORES MEDLINE- 60x90cm 25un  8.719875e+12         1
# 85    936    SANICAT CLUMPING VAINILLA-MANDARINA 8L  5.274204e+10        10
# 86    947  PROPLAN FELINE HYDRA-CARE HYDRAT 10x85gr  8.414042e+12         3
# 87    958    DESINCLOR CLORHEXIDINA- ACUOSA 1% 50ml  8.435458e+12         3
# 88    969                    LIBRELA 30mg iny 2x1ml  8.414042e+12         5
# 89    980                    DEXACORTONE 0,5mg 10cp  8.414042e+12         3
# 90    991                      DEXACORTONE 2mg 10cp  8.436589e+12         9
# 91   1002  CANINE I/D STEW POLLO-VEGETALES 12x354gr  8.414042e+12         6
# 92   1013                   PLASMORAL IMMUNITY 60cp  8.414042e+12         0
# 93   1024      PLAQTIV+ ADITIVO PARA- EL AGUA 500ml  8.414042e+12         2
# 94   1035       HEPATOSIL PLUS RAZAS- PEQUEÑAS 60cp  8.414042e+12         5
# 95   1046       HEPATOSIL PLUS RAZAS- MEDIANAS 30cp  3.411112e+12         7
# 96   1057                   VETILEA GASTRO GEL 50ml           NaN         1
# 97   1068        HEPATOSIL PLUS RAZAS- GRANDES 30cp           NaN         8
# 98   1079                      VETGASTRIL PLUS 20ml           NaN        10
# 99   1090                      VETGASTRIL PLUS 50ml           NaN         8
# 100  1101               IRC-VET GEL PERRO GATO 50ml           NaN         7
# 101  1112                    DERMIPRED 20mg 10x10cp           NaN         9

# %%
# Ordena el DataFrame por la columna "name"
df = df.sort_values(by='name')

# Define el número de divisiones
n = 20

# Calcula el número de elementos por división
division_size = len(df) // n

# Crea una lista con el número de estanterías para cada fila
estanteria = [i // division_size for i in range(len(df))]

# Añade la columna "estanteria" al DataFrame
df['estanteria'] = estanteria

# Muestra las primeras filas del DataFrame para verificar los cambios
print(df.head())
# Out:
#      id                                      name           ean  cantidad  \
# 1    12               ADTAB GATO 12mg 0,5-2kg 1cp  5.420037e+12         5
# 2    23                 ADTAB GATO 48mg 2-8kg 1cp  5.420037e+12         1
# 23  254  AGUJA STERICAN AMARILLA-20G 0,9X25mm100u  4.049501e+12         6
# 24  265   AGUJA STERICAN AZUL 23G- 0,6x25mm 100un  4.052200e+12         1
# 25  276  AGUJA STERICAN NARANJA-25G 0,5x16mm100un  8.414042e+12         4
#
#     estanteria
# 1            0
# 2            0
# 23           0
# 24           0
# 25           0

# %%
pd.set_option('display.max_rows', None)

# %%
df
# Out:
#        id                                      name           ean  cantidad  \
# 1      12               ADTAB GATO 12mg 0,5-2kg 1cp  5.420037e+12         5
# 2      23                 ADTAB GATO 48mg 2-8kg 1cp  5.420037e+12         1
# 23    254  AGUJA STERICAN AMARILLA-20G 0,9X25mm100u  4.049501e+12         6
# 24    265   AGUJA STERICAN AZUL 23G- 0,6x25mm 100un  4.052200e+12         1
# 25    276  AGUJA STERICAN NARANJA-25G 0,5x16mm100un  8.414042e+12         4
# 39    430               ANIMA STRATH TOMILLO- 100ml  8.713184e+12         8
# 46    507              BRAVECTO 1000mg 20-40kg 1tab  3.411112e+12         0
# 47    518              BRAVECTO 1400mg 40-56kg 1tab  3.660176e+12         1
# 44    485              BRAVECTO 250mg 4,5-10kg 1tab           NaN         5
# 45    496               BRAVECTO 500mg 10-20kg 1tab  3.660176e+12        10
# 67    738                            BUTOMIDOR 10ml  5.274203e+10         2
# 0       1             CALIERCORTIN 4mg/ml- 50ml iny  8.422320e+12         1
# 73    804      CANINE GASTROINTESTINAL- BIOME 1,5kg  8.436026e+12         6
# 91   1002  CANINE I/D STEW POLLO-VEGETALES 12x354gr  8.414042e+12         6
# 13    144                     CANINSULIN 10x2,50ml-  8.713184e+12         9
# 64    705           CARPRODYL QUADRI 120mg- x 120cp  7.613203e+12         3
# 65    716            CARPRODYL QUADRI 50mg x- 100cp  8.422320e+12         8
# 48    529                        CARPROX 20mg 100cp  8.414042e+12         2
# 16    177                  CLEAN AURAL CANINO 100ml           NaN         9
# 5      56                             CONOFITE 20ml  5.703188e+12         7
# 22    243           CONTENEDOR PARA- MUESTRAS 150ml  4.030539e+12         9
# 50    551            CONTENEDOR PARA- MUESTRAS 60ml  8.436026e+12         9
# 49    540                           CONTINENZA 50ml  8.436026e+12         5
# 38    419                              DAFORTE 20ml  8.713184e+12         6
# 42    463                              DAFORTE 50ml  8.470006e+12         2
# 21    232                          DEPO-MODERIN 5ml  4.022496e+12         3
# 101  1112                    DERMIPRED 20mg 10x10cp           NaN         9
# 87    958    DESINCLOR CLORHEXIDINA- ACUOSA 1% 50ml  8.435458e+12         3
# 20    221                          DEXABIOPEN 100ml  4.022495e+12         2
# 89    980                    DEXACORTONE 0,5mg 10cp  8.414042e+12         3
# 90    991                      DEXACORTONE 2mg 10cp  8.436589e+12         9
# 27    298               DISCOFIX C/ALARGADERA- 75cm  8.713184e+12         9
# 84    925         EMPAPADORES MEDLINE- 60x90cm 25un  8.719875e+12         1
# 29    320       ESPARADRAPO OMNIPLAST- CARNE 5cmx5m           NaN        10
# 60    661          FORTEKOR PLUS- 1,25/2,5mg 30tabs  3.700455e+12         4
# 4      45                FORTEKOR SABOR 2,5mg- 28cp  5.703188e+12         8
# 14    155                          GLUCANTIME 5x5ml  8.436530e+12         5
# 97   1068        HEPATOSIL PLUS RAZAS- GRANDES 30cp           NaN         8
# 95   1046       HEPATOSIL PLUS RAZAS- MEDIANAS 30cp  3.411112e+12         7
# 94   1035       HEPATOSIL PLUS RAZAS- PEQUEÑAS 60cp  8.414042e+12         5
# 41    452            HYALORAL CACHORRO Y- GATO 50ml  8.713184e+12         4
# 32    353           HYALORAL RZ GDES Y- GIGAN 120cp  8.414042e+12         3
# 40    441           HYALORAL RZ GDES Y- GIGAN 360cp  8.713184e+12         3
# 9     100                              IRC-VET 60cp  5.701170e+12         9
# 100  1101               IRC-VET GEL PERRO GATO 50ml           NaN         7
# 26    287    JERINGA INJEKT 2CUERPOS- S/A 2ml 100un  8.437003e+12         7
# 54    595                        LACRISTAL NEO 10ml  5.420037e+12        10
# 63    694                  LETIFEND LEISHMANIA 10ds  8.436026e+12         9
# 33    364                              LEVENTA 30ml  8.436021e+12         8
# 51    562                          LIBEO 10mg 120cp  8.436026e+12         1
# 88    969                    LIBRELA 30mg iny 2x1ml  8.414042e+12         5
# 15    166                            LUBRITHAL 10gr  8.436026e+12         2
# 37    408                       MELOXIDYL GATO 15ml  4.028692e+12         4
# 52    573                   MELOXIDYL GATO oral 5ml  8.436026e+12         4
# 71    782                           MERLIN 65cm 2un  8.436026e+12         1
# 72    793                             NACOTIL 125ml  8.436026e+12         4
# 3      34                      NICILAN 200/50 120cp  8.437003e+12         4
# 81    892                      OMNICARDIO PLUS 60cp  8.436005e+12         0
# 36    397                           OMNIMATRIX 20gr  8.414042e+12         7
# 8      89                              OTINET 125ml  3.661103e+12         8
# 6      67      OTOCLEAN LIMPIADOR- OTOLOGICO 18x5ml  5.703188e+12         7
# 7      78                             OXISPEED 60cp  8.713184e+12         5
# 12    133        PAÑO BUSTER POLIETILENO- 120x120cm  8.713184e+12         6
# 11    122          PAÑO BUSTER POLIETILENO- 60x90cm  8.410357e+12        10
# 10    111         PAÑO BUSTER POLIETILENO- 90x120cm  5.701170e+12         0
# 93   1024      PLAQTIV+ ADITIVO PARA- EL AGUA 500ml  8.414042e+12         2
# 83    914  PLASMORAL DIGEST RZ GDE-Y GIGAN 30sobres  8.719875e+12         1
# 82    903  PLASMORAL DIGEST RZ PEQ- Y MED 30 sobres  8.436026e+12         7
# 92   1013                   PLASMORAL IMMUNITY 60cp  8.414042e+12         0
# 61    672                   PREDNICORTONE 20mg 30cp  9.010854e+12         3
# 62    683                    PREDNICORTONE 5mg 30cp  8.429949e+12        10
# 70    771   PROLONGADOR REGULADOR- FLUJO 59cm 4,1ml  3.411113e+12         9
# 86    947  PROPLAN FELINE HYDRA-CARE HYDRAT 10x85gr  8.414042e+12         3
# 28    309        PROPOFOL LIPURO 1%- BRAUN VET 50ml  5.701170e+12         4
# 85    936    SANICAT CLUMPING VAINILLA-MANDARINA 8L  5.274204e+10        10
# 18    199                         SCALIBOR GDE 65cm           NaN         7
# 19    210                         SCALIBOR PEQ 48cm           NaN         3
# 35    386                                SEDIN 10ml  8.414042e+12         6
# 43    474                      SEMINTRA 4MG/ML 30ML  8.437012e+12         2
# 58    639         SIMPARICA PERROS 10-20kg 40mg 3cp  3.411112e+12        10
# 59    650         SIMPARICA PERROS 20-40kg 80mg 3cp  3.411112e+12         1
# 57    628          SIMPARICA PERROS 5-10kg 20mg 3cp  8.431167e+12         3
# 78    859         SIMPARICA TRIO PERROS 10-20kg 3cp  8.414042e+12         5
# 79    870         SIMPARICA TRIO PERROS 20-40kg 3cp           NaN         9
# 77    848          SIMPARICA TRIO PERROS 5-10kg 3cp  8.414042e+12         2
# 66    727                        SOLIPHEN 60mg 60cp  8.414042e+12         0
# 69    760  STRONGHOLD PLUS GATO 30/5mg 2,5-5kg 6pip  3.411113e+12         2
# 17    188                             T-61 50ml iny           NaN         8
# 68    749                      TUSHEEL JARABE 150ml  3.411113e+12         8
# 75    826            VECTRA 3D PERRO 10-25kg  12pip  3.411113e+12         2
# 76    837            VECTRA 3D PERRO 25-40kg  12pip  5.600788e+12         8
# 74    815             VECTRA 3D PERRO 4-10kg  12pip           NaN         5
# 30    331           VENDA ELASTICA LASTOTEL- 6cmx4m  5.600788e+12         1
# 56    617             VERSICAN PLUS DHPPIL4-25dosis  3.858889e+12         5
# 55    606            VERSICAN PLUS DHPPIL4R-25dosis  3.858889e+12         4
# 98   1079                      VETGASTRIL PLUS 20ml           NaN        10
# 99   1090                      VETGASTRIL PLUS 50ml           NaN         8
# 96   1057                   VETILEA GASTRO GEL 50ml           NaN         1
# 34    375                       VETORYL 10mg 30caps  8.414042e+12         0
# 31    342                         VETREGUL GEL 50ml  3.411113e+12        10
# 80    881                     ZELYS 1,25mg 8x12tabs  7.613039e+12        10
# 53    584     ZODON PERRO Y GATO ORAL- 25mg/ml 20ml  8.436026e+12         7
#
#      estanteria
# 1             0
# 2             0
# 23            0
# 24            0
# 25            0
# 39            1
# 46            1
# 47            1
# 44            1
# 45            1
# 67            2
# 0             2
# 73            2
# 91            2
# 13            2
# 64            3
# 65            3
# 48            3
# 16            3
# 5             3
# 22            4
# 50            4
# 49            4
# 38            4
# 42            4
# 21            5
# 101           5
# 87            5
# 20            5
# 89            5
# 90            6
# 27            6
# 84            6
# 29            6
# 60            6
# 4             7
# 14            7
# 97            7
# 95            7
# 94            7
# 41            8
# 32            8
# 40            8
# 9             8
# 100           8
# 26            9
# 54            9
# 63            9
# 33            9
# 51            9
# 88           10
# 15           10
# 37           10
# 52           10
# 71           10
# 72           11
# 3            11
# 81           11
# 36           11
# 8            11
# 6            12
# 7            12
# 12           12
# 11           12
# 10           12
# 93           13
# 83           13
# 82           13
# 92           13
# 61           13
# 62           14
# 70           14
# 86           14
# 28           14
# 85           14
# 18           15
# 19           15
# 35           15
# 43           15
# 58           15
# 59           16
# 57           16
# 78           16
# 79           16
# 77           16
# 66           17
# 69           17
# 17           17
# 68           17
# 75           17
# 76           18
# 74           18
# 30           18
# 56           18
# 55           18
# 98           19
# 99           19
# 96           19
# 34           19
# 31           19
# 80           20
# 53           20

# %%
df.to_csv("data_final.csv")

# %%
cell_list = [f"cell{i}" for i in range(1, 81)]

# %%
cell_list
# Out:
# ['cell1',
#  'cell2',
#  'cell3',
#  'cell4',
#  'cell5',
#  'cell6',
#  'cell7',
#  'cell8',
#  'cell9',
#  'cell10',
#  'cell11',
#  'cell12',
#  'cell13',
#  'cell14',
#  'cell15',
#  'cell16',
#  'cell17',
#  'cell18',
#  'cell19',
#  'cell20',
#  'cell21',
#  'cell22',
#  'cell23',
#  'cell24',
#  'cell25',
#  'cell26',
#  'cell27',
#  'cell28',
#  'cell29',
#  'cell30',
#  'cell31',
#  'cell32',
#  'cell33',
#  'cell34',
#  'cell35',
#  'cell36',
#  'cell37',
#  'cell38',
#  'cell39',
#  'cell40',
#  'cell41',
#  'cell42',
#  'cell43',
#  'cell44',
#  'cell45',
#  'cell46',
#  'cell47',
#  'cell48',
#  'cell49',
#  'cell50',
#  'cell51',
#  'cell52',
#  'cell53',
#  'cell54',
#  'cell55',
#  'cell56',
#  'cell57',
#  'cell58',
#  'cell59',
#  'cell60',
#  'cell61',
#  'cell62',
#  'cell63',
#  'cell64',
#  'cell65',
#  'cell66',
#  'cell67',
#  'cell68',
#  'cell69',
#  'cell70',
#  'cell71',
#  'cell72',
#  'cell73',
#  'cell74',
#  'cell75',
#  'cell76',
#  'cell77',
#  'cell78',
#  'cell79',
#  'cell80']
